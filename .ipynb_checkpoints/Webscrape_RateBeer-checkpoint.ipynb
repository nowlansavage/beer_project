# %% [markdown]
# # Scrapnig RateBeer

# %%
#dependancies
from bs4 import BeautifulSoup
import requests
import pandas as pd
from selenium import webdriver
import time

# %% [markdown]
# ## Get List of Styles

# %%
#scrape RateBeer for list 
base_url = 'https://www.ratebeer.com'
response = requests.get(base_url+'/beerstyles/')
soup = BeautifulSoup(response.text, 'html.parser')

# %%
#get all of the list elements
styleGroups = soup.find_all('ul', class_="styleGroup")

# %%
#go through the style groupings
styles=[]
links=[]
for i in range(0,7):
    results = styleGroups[i].find_all('li')
    
    #loop through each style within the grouping
    for result in results:

        #error handling
        try:
            #Get Beer Styles
            beer_style=result.find('a').text
            #Get hrefs to those styles to scrape 
            link=result.a['href']

            #print only if it has a style and link 
            if (beer_style and link):
                styles.append(beer_style)
                links.append(link)
                print('-'*30)
                print(beer_style)
                print(link)
        except AttributeError as e:
            print(e)
# Out:
# ------------------------------
# Altbier / Sticke Alt
# /beerstyles/altbier-sticke-alt/2/
# ------------------------------
# BarleyWine / WheatWine / RyeWine
# /beerstyles/barleywine-wheatwine-ryewine/11/
# ------------------------------
# Bitter - Ordinary / Best
# /beerstyles/bitter-ordinary-best/20/
# ------------------------------
# Bitter - Premium / Strong / ESB
# /beerstyles/bitter-premium-strong-esb/101/
# ------------------------------
# Blonde Ale / Golden Ale
# /beerstyles/blonde-ale-golden-ale/54/
# ------------------------------
# Brown Ale
# /beerstyles/brown-ale/15/
# ------------------------------
# Brown Ale - Imperial
# /beerstyles/brown-ale-imperial/131/
# ------------------------------
# California Common / Steam Beer
# /beerstyles/california-common-steam-beer/42/
# ------------------------------
# Cream Ale
# /beerstyles/cream-ale/35/
# ------------------------------
# IIPA DIPA - Hazy / Double NEIPA
# /beerstyles/iipa-dipa-hazy-double-neipa/145/
# ------------------------------
# IIPA DIPA - Imperial / Double IPA
# /beerstyles/iipa-dipa-imperial-double-ipa/81/
# ------------------------------
# IPA
# /beerstyles/india-pale-ale/17/
# ------------------------------
# IPA - Belgian / Saison
# /beerstyles/ipa-belgian-saison/139/
# ------------------------------
# IPA - Black / Brown / Cascadian Dark
# /beerstyles/ipa-black-brown-cascadian-dark/114/
# ------------------------------
# IPA - Brut
# /beerstyles/ipa-brut/140/
# ------------------------------
# IPA - English
# /beerstyles/ipa-english/141/
# ------------------------------
# IPA - Flavored
# /beerstyles/ipa-flavored/142/
# ------------------------------
# IPA - Hazy / NEIPA
# /beerstyles/ipa-hazy-neipa/126/
# ------------------------------
# IPA - Milkshake
# /beerstyles/ipa-milkshake/143/
# ------------------------------
# IPA - Red
# /beerstyles/ipa-red/144/
# ------------------------------
# IPA - Rye
# /beerstyles/ipa-rye/146/
# ------------------------------
# IPA - Sour / Wild
# /beerstyles/ipa-sour-wild/147/
# ------------------------------
# IPA - White
# /beerstyles/ipa-white/148/
# ------------------------------
# ISA - Session IPA
# /beerstyles/isa-session-ipa/121/
# ------------------------------
# Kölsch / Kolsch-Style
# /beerstyles/kolsch-kolsch-style/39/
# ------------------------------
# Mild Ale
# /beerstyles/mild-ale/55/
# ------------------------------
# Old Ale
# /beerstyles/old-ale/76/
# ------------------------------
# Pale Ale
# /beerstyles/pale-ale/150/
# ------------------------------
# Pale Ale - American / APA
# /beerstyles/pale-ale-american-apa/18/
# ------------------------------
# Pale Ale - Australia / NZ
# /beerstyles/pale-ale-australia-nz/151/
# ------------------------------
# Pale Ale - Belgian
# /beerstyles/pale-ale-belgian/152/
# ------------------------------
# Pale Ale - English
# /beerstyles/pale-ale-english/16/
# ------------------------------
# /beerstyles/flavored-pumpkin-vegetables/134/
# ------------------------------
# Gotlandsdricka / Koduõlu / Sahti
# /beerstyles/gotlandsdricka-koduolu-sahti/116/
# ------------------------------
# Gruit
# /beerstyles/gruit/137/
# ------------------------------
# Kvass
# /beerstyles/kvass/149/
# ------------------------------
# Low / No Alcohol Beer - Dark
# /beerstyles/low-no-alcohol-beer-dark/179/
# ------------------------------
# Low / No Alcohol Beer - Pale
# /beerstyles/low-no-alcohol-beer-pale/75/
# ------------------------------
# Low / No Alcohol Beer - Wheat
# /beerstyles/low-no-alcohol-beer-wheat/166/
# ------------------------------
# Smoked - Other
# /beerstyles/smoked-other/168/
# ------------------------------
# Smoked - Rauchbier
# /beerstyles/smoked-rauchbier/41/
# ------------------------------
# Specialty Grain - Other
# /beerstyles/specialty-grain-other/106/
# ------------------------------
# Specialty Grain - Rye / Roggenbier
# /beerstyles/specialty-grain-rye-roggenbier/169/
# ------------------------------
# Traditional Ale - Other
# /beerstyles/traditional-ale-other/59/
# ------------------------------
# Unknown / Will Be Reclassified
# /beerstyles/unknown-will-be-reclassified/164/

# %% [markdown]
# ## Get Top 50 List for each Style

# %%
#create empty_df
master_df = pd.DataFrame(columns =['Rank','NAME', 'COUNT', 'ABV', 'SCORE', 'Style'])
#loop through all styles and get the top50 list

for style_link in links:
    beer_url = base_url+style_link
    driver =webdriver.Chrome('chromedriver')
    driver.get(beer_url)
    time.sleep(5)
    tables = pd.read_html(driver.page_source)
    beer_df=tables[0]
    beer_df['Style']= BeautifulSoup(driver.page_source, 'html').find('h1').text
    beer_df=beer_df.rename(columns={'Unnamed: 0': 'Rank'})
    master_df = pd.concat([master_df,beer_df])
    driver.quit()
master_df
# Out:
#    Rank                                           NAME COUNT   ABV  SCORE  \
# 0     1                           Uerige Doppel Sticke   933  8.5%   3.76
# 1     2                              Schumacher 1838er   117  5.0%   3.71
# 2     3                                Schlüssel Stike    12  6.0%   3.67
# 3     4                            Godspeed Oberkassel    18  4.4%   3.63
# 4     5                   Vrooden Doppelsticke Altbier    16  8.5%   3.63
# ..  ...                                            ...   ...   ...    ...
# 45   46                     Klostergården Alstadberger    99  6.5%   3.50
# 46   47             WRCLW Schöps Smoked Plums Porto BA    27  4.8%   3.50
# 47   48                       Olvalde Brynhildr's Gift    51  8.2%   3.50
# 48   49                        Blaugies Bière Darbyste   563  5.8%   3.49
# 49   50  Local Option Kentucky Common - Bourbon Barrel    60  6.5%   3.49
#
#                       Style
# 0      Altbier / Sticke Alt
# 1      Altbier / Sticke Alt
# 2      Altbier / Sticke Alt
# 3      Altbier / Sticke Alt
# 4      Altbier / Sticke Alt
# ..                      ...
# 45  Traditional Ale - Other
# 46  Traditional Ale - Other
# 47  Traditional Ale - Other
# 48  Traditional Ale - Other
# 49  Traditional Ale - Other
#
# [6092 rows x 6 columns]

# %%
# Out:
#    Unnamed: 0                          NAME  COUNT   ABV  SCORE  \
# 0           1          Uerige Doppel Sticke    933  8.5%   3.76
# 1           2             Schumacher 1838er    117  5.0%   3.71
# 2           3               Schlüssel Stike     12  6.0%   3.67
# 3           4           Godspeed Oberkassel     18  4.4%   3.63
# 4           5  Vrooden Doppelsticke Altbier     16  8.5%   3.63
#
#                   Style
# 0  Altbier / Sticke Alt
# 1  Altbier / Sticke Alt
# 2  Altbier / Sticke Alt
# 3  Altbier / Sticke Alt
# 4  Altbier / Sticke Alt
