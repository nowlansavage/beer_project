# %%
 # Import Matplot lib
import matplotlib
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
# Pandas
import pandas as pd
    
# SQL Alchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

# %%
# create engine for untappd

untappd_database_path = 'Sqlite_files/untappd.sqlite'
engine = create_engine(f"sqlite:///{untappd_database_path}")
conn = engine.connect()

# %%
untappd_data = pd.read_sql('SELECT * FROM untappd', conn)
untappd_data.head()
# Out:
#                                                 beer  \
# 0  0                                 King JJJuliusss
# 1  1          Rare Bourbon County Brand Stout (2010)
# 2  2   Bourbon County Brand Stout Vanilla Rye (2014)
# 3  3  Proprietor's Bourbon County Brand Stout (2014)
# 4  4                     Beer : Barrel : Time (2018)
#
#                       brewery                      style  \
# 0  Tree House Brewing Company    IPA - Imperial / Double
# 1       Goose Island Beer Co.  Stout - Imperial / Double
# 2       Goose Island Beer Co.  Stout - Imperial / Double
# 3       Goose Island Beer Co.  Stout - Imperial / Double
# 4        Side Project Brewing  Stout - Imperial / Double
#
#                                                 link        abv  rating
# 0  /b/tree-house-brewing-company-king-jjjuliusss/...   8.4% ABV    4.74
# 1  /b/goose-island-beer-co-rare-bourbon-county-br...    13% ABV    4.74
# 2  /b/goose-island-beer-co-bourbon-county-brand-s...  13.6% ABV    4.74
# 3  /b/goose-island-beer-co-proprietor-s-bourbon-c...  13.2% ABV    4.74
# 4  /b/side-project-brewing-beer-barrel-time-2018/...    15% ABV    4.74

# %%
# create engine for beer advocate 
advocate_database_path = 'Sqlite_files/beer_advocate_2017.sqlite'
engine = create_engine(f"sqlite:///{advocate_database_path}")
conn = engine.connect()

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()

advocate_data = pd.read_sql('SELECT * FROM beer_advocate_2017_ratings', conn)
advocate_data.head()
# Out:
#    index             brewery_name               beer_name  \
# 0      0          Vecchio Birraio            Sausa Weizen
# 1      1          Vecchio Birraio                Red Moon
# 2      2          Vecchio Birraio  Black Horse Black Beer
# 3      3          Vecchio Birraio              Sausa Pils
# 4      4  Caldera Brewing Company           Cauldron DIPA
#
#                              brewery_beer                      beer_style  \
# 0            Vecchio Birraio Sausa Weizen                      Hefeweizen
# 1                Vecchio Birraio Red Moon              English Strong Ale
# 2  Vecchio Birraio Black Horse Black Beer          Foreign / Export Stout
# 3              Vecchio Birraio Sausa Pils                 German Pilsener
# 4   Caldera Brewing Company Cauldron DIPA  American Double / Imperial IPA
#
#    beer_abv  review_overall
# 0       5.0             1.5
# 1       6.2             3.0
# 2       6.5             3.0
# 3       5.0             3.0
# 4       7.7             4.0

# %%
advocate_data.columns=['index','brewery','beer','brewery_beer','style','abv','rating']
advocate_data.head()
# Out:
#    index                  brewery                    beer  \
# 0      0          Vecchio Birraio            Sausa Weizen
# 1      1          Vecchio Birraio                Red Moon
# 2      2          Vecchio Birraio  Black Horse Black Beer
# 3      3          Vecchio Birraio              Sausa Pils
# 4      4  Caldera Brewing Company           Cauldron DIPA
#
#                              brewery_beer                           style  \
# 0            Vecchio Birraio Sausa Weizen                      Hefeweizen
# 1                Vecchio Birraio Red Moon              English Strong Ale
# 2  Vecchio Birraio Black Horse Black Beer          Foreign / Export Stout
# 3              Vecchio Birraio Sausa Pils                 German Pilsener
# 4   Caldera Brewing Company Cauldron DIPA  American Double / Imperial IPA
#
#    abv  rating
# 0  5.0     1.5
# 1  6.2     3.0
# 2  6.5     3.0
# 3  5.0     3.0
# 4  7.7     4.0

# %%
bad_cell = advocate_data[advocate_data['index']==277771].index
bad_cell
advocate_data.drop(bad_cell, inplace=True)
advocate_data.head()
# Out:
#    index                  brewery                    beer  \
# 0      0          Vecchio Birraio            Sausa Weizen
# 1      1          Vecchio Birraio                Red Moon
# 2      2          Vecchio Birraio  Black Horse Black Beer
# 3      3          Vecchio Birraio              Sausa Pils
# 4      4  Caldera Brewing Company           Cauldron DIPA
#
#                              brewery_beer                           style  \
# 0            Vecchio Birraio Sausa Weizen                      Hefeweizen
# 1                Vecchio Birraio Red Moon              English Strong Ale
# 2  Vecchio Birraio Black Horse Black Beer          Foreign / Export Stout
# 3              Vecchio Birraio Sausa Pils                 German Pilsener
# 4   Caldera Brewing Company Cauldron DIPA  American Double / Imperial IPA
#
#    abv  rating
# 0  5.0     1.5
# 1  6.2     3.0
# 2  6.5     3.0
# 3  5.0     3.0
# 4  7.7     4.0

# %%
beer_project_database_path = 'Sqlite_files/beer_project.sqlite'
engine = create_engine(f"sqlite:///{beer_project_database_path}")
conn = engine.connect()

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['breweries']

# %%
beer_project_data = pd.read_sql('SELECT * from breweries', conn)
beer_project_data.head()
# Out:
#    index                             name             website  \
# 0      0   Patton Block Grill and Brewpub
# 1      1                 (405) Brewing Co  www.405brewing.com
# 2      2                 (512) Brewing Co  www.512brewing.com
# 3      3   10 Torr Distilling and Brewing      www.10torr.com
# 4      4            10-56 Brewing Company
#
#                  address      city state
# 0    88-90 Public Square  Monmouth    MN
# 1         1716 Topeka St    Norman    MN
# 2  407 Radam Ln Ste F200    Austin    MN
# 3            490 Mill St      Reno    MN
# 4             2120 US-35      Knox    MN

# %%
beer_project_data.columns=['index','brewery','website','address','city','state']
beer_project_data.head()
# Out:
#    index                          brewery             website  \
# 0      0   Patton Block Grill and Brewpub
# 1      1                 (405) Brewing Co  www.405brewing.com
# 2      2                 (512) Brewing Co  www.512brewing.com
# 3      3   10 Torr Distilling and Brewing      www.10torr.com
# 4      4            10-56 Brewing Company
#
#                  address      city state
# 0    88-90 Public Square  Monmouth    MN
# 1         1716 Topeka St    Norman    MN
# 2  407 Radam Ln Ste F200    Austin    MN
# 3            490 Mill St      Reno    MN
# 4             2120 US-35      Knox    MN

# %%
# Out:
# 1586614

# %%
untappd_data.to_csv('untappd.csv',index=False)

# %%
advocate_data.to_csv('advocate.csv',index=False)

# %%
beer_project_data.to_csv('brewers_guild.csv',index=False)
